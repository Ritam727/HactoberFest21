# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings

# %%
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv('animes.csv').loc[:,['uid','title','members','synopsis']].rename(columns={'uid':'anime_id'})
df['title']=df['title'].str.lower()
df
# Out:
#        anime_id                                        title  members  \
# 0         28891                      haikyuu!! second season   489888
# 1         23273                      shigatsu wa kimi no uso   995473
# 2         34599                                made in abyss   581663
# 3          5114             fullmetal alchemist: brotherhood  1615084
# 4         31758             kizumonogatari iii: reiketsu-hen   214621
# ...         ...                                          ...      ...
# 19306     32979                                flip flappers   134252
# 19307       123                                fushigi yuugi    84407
# 19308      1281                             gakkou no kaidan    83093
# 19309       450  inuyasha movie 2: kagami no naka no mugenjo    71989
# 19310        87     mobile suit gundam: char's counterattack    29248
#
#                                                 synopsis
# 0      Following their participation at the Inter-Hig...
# 1      Music accompanies the path of the human metron...
# 2      The Abyss—a gaping chasm stretching down into ...
# 3      "In order for something to be obtained, someth...
# 4      After helping revive the legendary vampire Kis...
# ...                                                  ...
# 19306  Cocona is an average middle schooler living wi...
# 19307  While visiting the National Library, junior-hi...
# 19308  Years ago, all of the ghosts in a haunted scho...
# 19309  Inuyasha and company have finally destroyed Na...
# 19310  The year is Universal Century 0093. Char Aznab...
#
# [19311 rows x 4 columns]

# %%
df['synopsis']=df['synopsis'].str.replace('\r','')
df['synopsis']=df['synopsis'].str.replace('\n','')
df['synopsis']=df['synopsis'].fillna('')

for i in range(0,19311):
    df['synopsis'][i] = df['synopsis'][i].split("  [")[0]
    
df
# Out:
#        anime_id                                        title  members  \
# 0         28891                      haikyuu!! second season   489888
# 1         23273                      shigatsu wa kimi no uso   995473
# 2         34599                                made in abyss   581663
# 3          5114             fullmetal alchemist: brotherhood  1615084
# 4         31758             kizumonogatari iii: reiketsu-hen   214621
# ...         ...                                          ...      ...
# 19306     32979                                flip flappers   134252
# 19307       123                                fushigi yuugi    84407
# 19308      1281                             gakkou no kaidan    83093
# 19309       450  inuyasha movie 2: kagami no naka no mugenjo    71989
# 19310        87     mobile suit gundam: char's counterattack    29248
#
#                                                 synopsis
# 0      Following their participation at the Inter-Hig...
# 1      Music accompanies the path of the human metron...
# 2      The Abyss—a gaping chasm stretching down into ...
# 3      "In order for something to be obtained, someth...
# 4      After helping revive the legendary vampire Kis...
# ...                                                  ...
# 19306  Cocona is an average middle schooler living wi...
# 19307  While visiting the National Library, junior-hi...
# 19308  Years ago, all of the ghosts in a haunted scho...
# 19309  Inuyasha and company have finally destroyed Na...
# 19310  The year is Universal Century 0093. Char Aznab...
#
# [19311 rows x 4 columns]

# %%
df[df['title']=='dragon ball']
# Out:
#       anime_id        title  members  \
# 377        223  dragon ball   565538
# 6643       223  dragon ball   565538
#
#                                                synopsis
# 377   Gokuu Son is a young boy who lives in the wood...
# 6643  Gokuu Son is a young boy who lives in the wood...

# %%
df.to_csv('anime_dataset.csv')

# %%
df = pd.read_csv('anime_dataset.csv').iloc[:5000, 1:]
df = df.sort_values(by="anime_id").drop_duplicates(subset=["title"])

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=5000,stop_words='english')

# %%
tv = cv.fit_transform(df['synopsis'].astype('U')).toarray()

# %%
tv.shape
# Out:
# (4835, 5000)

# %%
cv.get_feature_names()
# Out:
# ['00',
#  '000',
#  '01',
#  '10',
#  '100',
#  '10th',
#  '11',
#  '12',
#  '12th',
#  '13',
#  '13th',
#  '14',
#  '15',
#  '15th',
#  '16',
#  '16th',
#  '17',
#  '18',
#  '19',
#  '1980s',
#  '1998',
#  '1999',
#  '19th',
#  '1st',
#  '20',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2015',
#  '2017',
#  '2018',
#  '2020',
#  '20th',
#  '21',
#  '21st',
#  '22',
#  '22nd',
#  '23',
#  '24',
#  '24th',
#  '25',
#  '26',
#  '27',
#  '28',
#  '29',
#  '2nd',
#  '30',
#  '300',
#  '31',
#  '3d',
#  '3rd',
#  '4th',
#  '50',
#  '500',
#  '5th',
#  '6th',
#  '7th',
#  '8th',
#  '90',
#  '9th',
#  'abandoned',
#  'abducted',
#  'abh',
#  'abilities',
#  'ability',
#  'able',
#  'abnormal',
#  'aboard',
#  'abroad',
#  'abruptly',
#  'absence',
#  'absent',
#  'absolute',
#  'absolutely',
#  'abuse',
#  'abusive',
#  'abyss',
#  'academic',
#  'academy',
#  'accept',
#  'acceptance',
#  'accepted',
#  'accepting',
#  'accepts',
#  'access',
#  'accident',
#  'accidentally',
#  'acclaimed',
#  'accompanied',
#  'accompanying',
#  'accomplish',
#  'according',
#  'account',
#  'accused',
#  'accustomed',
#  'ace',
#  'achieve',
#  'achieving',
#  'acquaintances',
#  'acquire',
#  'act',
#  'acting',
#  'action',
#  'actions',
#  'active',
#  'activities',
#  'actor',
#  'actors',
#  'actress',
#  'acts',
#  'actual',
#  'actually',
#  'ad',
#  'adapt',
#  'adaptation',
#  'adapted',
#  'adapts',
#  'add',
#  'added',
#  'addition',
#  'additional',
#  'adjust',
#  'admiral',
#  'adopted',
#  'adorable',
#  'adult',
#  'adults',
#  'advance',
#  'advanced',
#  'advances',
#  'advantage',
#  'adventure',
#  'adventurer',
#  'adventurers',
#  'adventures',
#  'adventurous',
#  'adversaries',
#  'advice',
#  'advisor',
#  'ae86',
#  'affair',
#  'affect',
#  'affection',
#  'affectionate',
#  'afraid',
#  'afterlife',
#  'aftermath',
#  'age',
#  'agency',
#  'agenda',
#  'agent',
#  'agents',
#  'ages',
#  'ago',
#  'agree',
#  'agreed',
#  'agrees',
#  'ahead',
#  'ai',
#  'aichi',
#  'aid',
#  'aided',
#  'aika',
#  'aiko',
#  'aim',
#  'aiming',
#  'aims',
#  'ainz',
#  'air',
#  'aired',
#  'airi',
#  'airing',
#  'aizawa',
#  'aka',
#  'akagi',
#  'akane',
#  'akari',
#  'akatsuki',
#  'akemi',
#  'aki',
#  'akihabara',
#  'akihiko',
#  'akihito',
#  'akimi',
#  'akina',
#  'akira',
#  'akito',
#  'akko',
#  'akuma',
#  'aladdin',
#  'album',
#  'alchemist',
#  'alchemy',
#  'alcoholic',
#  'alexander',
#  'alice',
#  'alien',
#  'aliens',
#  'alike',
#  'alive',
#  'alliance',
#  'allies',
#  'allow',
#  'allowed',
#  'allowing',
#  'allows',
#  'ally',
#  'alongside',
#  'alpha',
#  'alphonse',
#  'alter',
#  'altered',
#  'alternate',
#  'alternative',
#  'amano',
#  'amateur',
#  'amazing',
#  'ambition',
#  'ambitions',
#  'ambitious',
#  'america',
#  'american',
#  'amidst',
#  'amnesia',
#  'amon',
#  'amuro',
#  'amusement',
#  'ancient',
#  'android',
#  'androids',
#  'ane',
#  'angel',
#  'angels',
#  'anger',
#  'angry',
#  'anidb',
#  'animal',
#  'animals',
#  'animated',
#  'animation',
#  'animations',
#  'animators',
#  'anime',
#  'animenfo',
#  'aniplex',
#  'ann',
#  'anna',
#  'annerose',
#  'anniversary',
#  'announced',
#  'announces',
#  'annual',
#  'anonymous',
#  'anpanman',
#  'answer',
#  'answers',
#  'anthropomorphic',
#  'anti',
#  'antics',
#  'anymore',
#  'aoba',
#  'aoi',
#  'aoyama',
#  'apart',
#  'apartment',
#  'apocalyptic',
#  'app',
#  'apparent',
#  'apparently',
#  'appear',
#  'appearance',
#  'appearances',
#  'appeared',
#  'appearing',
#  'appears',
#  'appetite',
#  'apple',
#  'apprentice',
#  'approach',
#  'approached',
#  'approaches',
#  'approaching',
#  'april',
#  'aqua',
#  'arale',
#  'araragi',
#  'arata',
#  'arc',
#  'arcade',
#  'arcadia',
#  'archer',
#  'area',
#  'areas',
#  'aren',
#  'aria',
#  'arima',
#  'arisa',
#  'arise',
#  'arises',
#  'ark',
#  'arm',
#  'armed',
#  'armies',
#  'armor',
#  'armored',
#  'arms',
#  'army',
#  'arrested',
#  'arrival',
#  'arrive',
#  'arrived',
#  'arrives',
#  'arriving',
#  'art',
#  'arthur',
#  'artifact',
#  'artificial',
#  'artist',
#  'artists',
#  'arts',
#  'asagi',
#  'asahina',
#  'asami',
#  'ash',
#  'asia',
#  'aside',
#  'ask',
#  'asked',
#  'asking',
#  'asks',
#  'asleep',
#  'aspects',
#  'aspires',
#  'aspiring',
#  'assailant',
#  'assassin',
#  'assassinate',
#  'assassination',
#  'assassins',
#  'assault',
#  'assaulted',
#  'assaults',
#  'assigned',
#  'assignment',
#  'assist',
#  'assistance',
#  'assistant',
#  'association',
#  'astro',
#  'asuka',
#  'ataru',
#  'atelier',
#  'athena',
#  'athletic',
#  'atlas',
#  'atmosphere',
#  'atsuko',
#  'atsushi',
#  'attack',
#  'attacked',
#  'attacking',
#  'attacks',
#  'attain',
#  'attempt',
#  'attempted',
#  'attempting',
#  'attempts',
#  'attend',
#  'attending',
#  'attends',
#  'attention',
#  'attitude',
#  'attract',
#  'attracted',
#  'attraction',
#  'attractive',
#  'attracts',
#  'auction',
#  'audience',
#  'august',
#  'aunt',
#  'aura',
#  'austria',
#  'author',
#  'authorities',
#  'authority',
#  'autumn',
#  'available',
#  'avenge',
#  'average',
#  'avoid',
#  'await',
#  'awaited',
#  'awaits',
#  'awaken',
#  'awakened',
#  'awakens',
#  'award',
#  'aware',
#  'away',
#  'awkward',
#  'awry',
#  'aya',
#  'ayaka',
#  'ayame',
#  'ayane',
#  'ayano',
#  'ayase',
#  'ayumi',
#  'ayumu',
#  'aznable',
#  'azuma',
#  'azusa',
#  'babies',
#  'baby',
#  'background',
#  'backkom',
#  'bad',
#  'bag',
#  'bakabt',
#  'balance',
#  'ball',
#  'bamboo',
#  'band',
#  'bandai',
#  'bandits',
#  'banished',
#  'bar',
#  'barely',
#  'bargained',
#  'baron',
#  'base',
#  'baseball',
#  'based',
#  'basic',
#  'basket',
#  'basketball',
#  'bat',
#  'bath',
#  'batou',
#  'battle',
#  'battlefield',
#  'battles',
#  'battleship',
#  'battling',
#  'bd',
#  'beach',
#  'bear',
#  'bears',
#  'beast',
#  'beasts',
#  'beat',
#  'beaten',
#  'beats',
#  'beautiful',
#  'beauty',
#  'beck',
#  'bed',
#  'befriend',
#  'befriends',
#  'began',
#  'begging',
#  'begin',
#  'beginning',
#  'begins',
#  'begun',
#  'behavior',
#  'beings',
#  'believe',
#  'believed',
#  'believes',
#  'believing',
#  'bell',
#  'belongs',
#  'beloved',
#  'belt',
#  'beneath',
#  'bent',
#  'berserk',
#  'best',
#  'bet',
#  'betrayal',
#  'betrayed',
#  'better',
#  'bible',
#  'bicycle',
#  'big',
#  'bigger',
#  'biggest',
#  'bike',
#  'bird',
#  'birth',
#  'birthday',
#  'biscotti',
#  'bishop',
#  'bit',
#  'bizarre',
#  'black',
#  'blackmail',
#  'blade',
#  'bleak',
#  'blend',
#  'blessed',
#  'blessing',
#  'blind',
#  'blond',
#  'blood',
#  'blooded',
#  'bloodline',
#  'bloodshed',
#  'bloodthirsty',
#  'bloody',
#  'bloom',
#  'blossom',
#  'blossoms',
#  'blown',
#  'blu',
#  'blue',
#  'board',
#  'boarding',
#  'boat',
#  'bodies',
#  'body',
#  'bodyguard',
#  'boisterous',
#  'boku',
#  'bond',
#  'bondage',
#  'bonds',
#  'bonus',
#  'book',
#  'books',
#  'bored',
#  'borgman',
#  'boring',
#  'born',
#  'boss',
#  'bouken',
#  'bound',
#  'bounty',
#  'box',
#  'boxer',
#  'boxing',
#  'boy',
#  'boyfriend',
#  'boys',
#  'brain',
#  'branch',
#  'brand',
#  'brave',
#  'bravely',
#  'bread',
#  'break',
#  'breaking',
#  'breaks',
#  'breasts',
#  'breath',
#  'brewing',
#  'bride',
#  'bridge',
#  'brief',
#  'brigade',
#  'bright',
#  'brilliant',
#  'brimming',
#  'bring',
#  'bringing',
#  'brings',
#  'brink',
#  'britannia',
#  'broadcast',
#  'broken',
#  'broly',
#  'brother',
#  'brothers',
#  'brought',
#  'brutal',
#  'budding',
#  'build',
#  'building',
#  'buildings',
#  'built',
#  'bullied',
#  'bullies',
#  'bullying',
#  'bunch',
#  'bundled',
#  'bunny',
#  'bureau',
#  'buried',
#  'burning',
#  'bus',
#  'business',
#  'businessman',
#  'busters',
#  'busty',
#  'busy',
#  'butler',
#  'buys',
#  'cafe',
#  'café',
#  'called',
#  'calling',
#  'calls',
#  'calm',
#  'came',
#  'camera',
#  'camp',
#  'campaign',
#  'camping',
#  'campus',
#  'candidate',
#  'candidates',
#  'candy',
#  'cannon',
#  'capable',
#  'capital',
#  'capsule',
#  'captain',
#  'capture',
#  'captured',
#  'capturing',
#  'car',
#  'card',
#  'cards',
#  'care',
#  'career',
#  'carefree',
#  'caring',
#  'carnal',
#  'carries',
#  'carry',
#  'carrying',
#  'cart',
#  'cartoon',
#  'case',
#  'cases',
#  'cash',
#  'cast',
#  'castle',
#  'cat',
#  'catastrophe',
#  'catastrophic',
#  'catch',
#  'catches',
#  'catching',
#  'cats',
#  'caught',
#  'cause',
#  'caused',
#  'causes',
#  'causing',
#  'cave',
#  'cd',
#  'celebrate',
#  'celebration',
#  'celestial',
#  'cell',
#  'center',
#  'centered',
#  'centers',
#  'central',
#  'centuries',
#  'century',
#  'ceremony',
#  'certain',
#  'certainly',
#  'cg',
#  'cgi',
#  'chain',
#  'chairman',
#  'chako',
#  'challenge',
#  'challenged',
#  'challenges',
#  'challenging',
#  'champion',
#  'championship',
#  'chan',
#  'chance',
#  'change',
#  'changed',
#  'changes',
#  'changing',
#  'channel',
#  'chaos',
#  'chaotic',
#  'chapter',
#  'chapters',
#  'char',
#  'character',
#  'characters',
#  'charge',
#  'charged',
#  'chariot',
#  'charismatic',
#  'charm',
#  'charming',
#  'charms',
#  'chase',
#  'chased',
#  'chases',
#  'chasing',
#  'check',
#  'cheer',
#  'cheerful',
#  'chef',
#  'cherry',
#  'chi',
#  'chiaki',
#  'chibi',
#  'chidori',
#  'chief',
#  'chihaya',
#  'chihiro',
#  'chika',
#  'child',
#  'childhood',
#  'childish',
#  'children',
#  'china',
#  'chinese',
#  'chisato',
#  'chise',
#  'chitose',
#  'chiyo',
#  'chizuru',
#  'choice',
#  'choices',
#  'choose',
#  'chooses',
#  'chose',
#  'chosen',
#  'christmas',
#  'chronicle',
#  'chronicles',
#  'chuck',
#  'church',
#  'chuunibyou',
#  'ciel',
#  'cinderella',
#  'cinema',
#  'cinemas',
#  'cinque',
#  'circle',
#  'circumstances',
#  'circus',
#  'cities',
#  'citizens',
#  'city',
#  'civil',
#  'civilization',
#  'civilizations',
#  'clad',
#  'claim',
#  'claiming',
#  'claims',
#  'clan',
#  'clannad',
#  'clans',
#  'clash',
#  'class',
#  'classes',
#  'classic',
#  'classical',
#  'classmate',
#  'classmates',
#  'classroom',
#  'claude',
#  'claus',
#  'clean',
#  'cleaning',
#  'clear',
#  'click',
#  'client',
#  'clients',
#  'climax',
#  'climb',
#  'clip',
#  'clock',
#  'close',
#  'closed',
#  'closely',
#  'closer',
#  'closest',
#  'clothes',
#  'clothing',
#  'cloud',
#  'clouds',
#  'club',
#  'clubs',
#  'clue',
#  'clues',
#  'clumsy',
#  'clutches',
#  'coach',
#  'coastal',
#  'cobra',
#  'code',
#  'coffee',
#  'coincidentally',
#  'cold',
#  'collaboration',
#  'collaborative',
#  'collapse',
#  'colleague',
#  'colleagues',
#  'collect',
#  'collecting',
#  'collection',
#  'collects',
#  'college',
#  'colonel',
#  'colonies',
#  'colony',
#  'color',
#  'colored',
#  'colorful',
#  'com',
#  'combat',
#  'combine',
#  'combined',
#  'come',
#  'comedic',
#  'comedy',
#  'comes',
#  'comet',
#  'comfort',
#  'comic',
#  'comics',
#  'coming',
#  'command',
#  'commander',
#  'commercial',
#  'commercials',
#  'commissioned',
#  'commit',
#  'committed',
#  'committee',
#  'committing',
#  'common',
#  'community',
#  'companion',
#  'companions',
#  'company',
#  'compete',
#  'competing',
#  'competition',
#  'competitive',
#  'compilation',
#  'complete',
#  'completed',
#  'completely',
#  'completing',
#  'complex',
#  'complicated',
#  'composed',
#  'comprised',
#  'computer',
#  'comrade',
#  'comrades',
#  'conan',
#  'concept',
#  'concerned',
#  'concerning',
#  'concert',
#  'conclusion',
#  'condition',
#  'conditions',
#  'conductor',
#  'confess',
#  'confessed',
#  'confesses',
#  'confession',
#  'confidence',
#  'confident',
#  'conflict',
#  'conflicts',
#  'confront',
#  'confronted',
#  'confronts',
#  'confused',
#  'confusion',
#  'connect',
#  'connected',
#  'connecting',
#  'connection',
#  'connections',
#  'conquer',
#  'conquered',
#  'conquering',
#  'conquest',
#  'conscience',
#  'consciousness',
#  'consecutive',
#  'consequences',
#  'consider',
#  'considered',
#  'considers',
#  'consisting',
#  'consists',
#  'conspiracy',
#  'constant',
#  'constantly',
#  'constructed',
#  'construction',
#  'consumed',
#  'consumes',
#  'contact',
#  'contain',
#  'contained',
#  'containing',
#  'contains',
#  'content',
#  'contest',
#  'contests',
#  'continent',
#  'continually',
#  'continuation',
#  'continue',
#  'continued',
#  'continues',
#  'continuing',
#  'contract',
#  'contracts',
#  'contrast',
#  'control',
#  'controlled',
#  'controlling',
#  'controls',
#  'convenience',
#  'conversation',
#  'converted',
#  'convey',
#  'convince',
#  'convinced',
#  'cooking',
#  'cool',
#  'cooperate',
#  'cop',
#  'copy',
#  'core',
#  'corner',
#  'corporate',
#  'corporation',
#  'corps',
#  'corrupt',
#  'corruption',
#  'cosmic',
#  'cosplay',
#  'cost',
#  'costume',
#  'couldn',
#  'council',
#  'count',
#  'counter',
#  'countless',
#  'countries',
#  'country',
#  'countryside',
#  'coup',
#  'couple',
#  'couples',
#  'courage',
#  'course',
#  'court',
#  'cousin',
#  'cover',
#  'covering',
#  'covers',
#  'covert',
#  'cow',
#  'crack',
#  'cranston',
#  'crash',
#  'crashes',
#  'crayon',
#  'crazed',
#  'crazy',
#  'cream',
#  'create',
#  'created',
#  'creates',
#  'creating',
#  'creation',
#  'creator',
#  'creature',
#  'creatures',
#  'crew',
#  'cries',
#  'crime',
#  'crimes',
#  'criminal',
#  'criminals',
#  'crimson',
#  'crisis',
#  ...]

# %%
from sklearn.metrics.pairwise import cosine_similarity
cos_sim = cosine_similarity(tv)
cos_sim
# Out:
# array([[1.        , 0.17770466, 0.04173112, ..., 0.        , 0.03800209,
#         0.        ],
#        [0.17770466, 1.        , 0.09393364, ..., 0.        , 0.0285133 ,
#         0.        ],
#        [0.04173112, 0.09393364, 1.        , ..., 0.        , 0.01339179,
#         0.        ],
#        ...,
#        [0.        , 0.        , 0.        , ..., 1.        , 0.        ,
#         0.        ],
#        [0.03800209, 0.0285133 , 0.01339179, ..., 0.        , 1.        ,
#         0.        ],
#        [0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#         1.        ]])

# %%
def recommender(anime):
    index = df[df['title'] == anime].index[0]
    distances = sorted(list(enumerate(cos_sim[index])),reverse=True,key = lambda x: x[1])
    for i in distances[1:10]:
        print(df.iloc[i[0]].title)

# %%
recommender('made in abyss')
# Out:
# free!: eternal summer - kindan no all hard!
# bang dream!: asonjatta!
# shin strange+ special
# steins;gate 0: kesshou takei no valentine - bittersweet intermedio
# strange+ special
# monhun nikki girigiri airou mura: airou kiki ippatsu specials
# choboraunyopomi gekijou dai ni maku ai mai mii: mousou catastrophe special
# angel beats! specials
# gakuen handsome special

# %%
recommender('dragon ball')
# Out:
# suki da yo!
# matou kitan zankan!
# letchu, getchu, saru getchu
# ryuu seiki
# life no color
# ishuzoku reviewers
# sakura no mori
# toufu kozou
# maki-chan to now.

# %%
recommender('death note')
# Out:
# doubutsu no mori
# koihime
# mayoiga
# mahoujin guruguru
# maid ane
# utawarerumono
# robin-kun to 100 nin no otomodachi
# kaitei daisensou: ai no 20,000 miles
# karakara-sama no himitsu

# %%
recommender('one piece')
# Out:
# kisaku spirit
# shusaku liberty
# yaruki manman
# tsuma to mama to boin
# jii tousaku
# hatsu inu 2 the animation: strange kind of woman - again
# kyouiku shidou the animation
# jinkou shoujo: henshin sex android
# bikyaku seido kaichou ai
